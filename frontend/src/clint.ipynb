# %%
import pandas as pd
df = pd.read_csv("D:/dashboard/dashboard_project_full_data/dashboard_project_python_only/all_data/client_stock_data.csv")

# %%
df
# Out:
#    Person        Stock  Nse code  Buy Price  Quantity  Current Price  \
# 0   Dipak    ANGELONE        NaN    2525.53        11           3800
# 1   Dipak   ASIANPAINT       NaN    2377.66        16           1500
# 2   Dipak     AXISBANK       NaN    1072.99         0            330
# 3   Dipak   BAJAJ-AUTO       NaN    8246.83         0            650
# 4   Dipak   BAJAJFINSV       NaN    1600.00         0            900
# 5   Dipak     BAJAJHFL       NaN     115.68         0           2400
# 6   Dipak  BERGERPAINT       NaN    2300.00         0           2200
# 7   Dipak          BSE       NaN     900.00         0            880
# 8   Dipak         CAMS       NaN    1150.00         0           1300
# 9   Dipak        CANBK       NaN     180.00         0            200
# 10  Dipak        CIPLA       NaN     750.00         0            800
# 11  Dipak    COALINDIA       NaN     280.00         0            300
# 12  Dipak      ETERNAL       NaN    9500.00         0           9800
# ...

# %%
df_all = pd.read_csv(r"C:\Users\deepa\Downloads\query-results (5).csv")

# %%
merged_df = pd.merge(
    df,
   df_all,
    left_on='Nse code',
    right_on='symbol',
    how='left'
)

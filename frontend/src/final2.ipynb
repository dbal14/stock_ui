# %%
import yfinance as yf
import pandas as pd
import warnings
import os
import numpy as np
import ast
import re

warnings.filterwarnings("ignore")

# desired single-level columns (yfinance standard)
desired_cols = ['symbol','Close', 'High', 'Low', 'Open', 'Volume']
df_all = pd.DataFrame(columns=desired_cols)
tickers =  [
    "360ONE", "3MINDIA", "ABB", "ABLBL", "ABREL", "AADHARHFC", "AARTIIND", "AAVAS",
    "ABBOTINDIA", "ACC", "ACMESOLAR", "ACE", "ADANIENSOL", "ADANIENT", "ADANIGREEN",
    "ADANIPORTS", "ADANIPOWER", "ATGL", "ABSLAMC", "ABFRL", "ABCAPITAL", "AEGISLOG",
    "AEGISVOPAK", "AFCONS", "AFFLE", "AIAENG", "AJANTPHARM", "AKUMS", "AKZOINDIA",
    "APLLTD", "ALKEM", "ALKYLAMINE", "ALOKINDS", "ARE&M", "AMBER", "AMBUJACEM",
    "ANANDRATHI", "ANANTRAJ", "ANGELONE", "APARINDS", "APLAPOLLO", "APOLLOHOSP",
    "APOLLOTYRE", "APTUS", "ASAHIINDIA", "ASHOKLEY", "ASIANPAINT", "ASTERDM",
    "ASTRAL", "ATHERENERG", "ATUL", "AUBANK", "AUROPHARMA", "AIIL",
    "DMART", "AWL", "AXISBANK", "BHEL", "BPCL", "BAJAJ-AUTO", "BAJFINANCE", "BAJAJFINSV",
    "BAJAJHLDNG", "BAJAJHFL", "BALKRISIND", "BALRAMCHIN", "BANDHANBNK", "BANKBARODA",
    "BANKINDIA", "MAHABANK", "BASF", "BATAINDIA", "BAYERCROP", "BEML", "BERGEPAINT",
    "BDL", "BEL", "BHARATFORG", "BHARTIARTL", "BHARTIHEXA", "BIKAJI", "BIOCON",
    "BSOFT", "BLS", "BLUEDART", "BLUEJET", "BLUESTARCO", "BBTC", "BOSCHLTD", "FIRSTCRY",
    "BRIGADE", "BRITANNIA", "BSE", "CDSL", "CHENNPETRO", "MAPMYINDIA", "CAMPUS", "CAMS",
    "CANFINHOME", "CANBK", "CAPLIPOINT", "CGCL", "CARBORUNIV", "CASTROLIND", "CCL",
    "CEATLTD", "CENTRALBK", "CENTURYPLY", "CERA", "CESC", "CGPOWER", "CHALET",
    "CHAMBLFERT", "CHOICEIN", "CHOLAHLDNG", "CHOLAFIN", "CIPLA", "CUB", "CLEAN",
    "COALINDIA", "COCHINSHIP", "COFORGE", "COHANCE", "COLPAL", "CONCORDBIO", "CONCOR",
    "COROMANDEL", "CRAFTSMAN", "CREDITACC", "CRISIL", "CROMPTON", "CUMMINSIND",
    "CYIENT", "DABUR", "DALBHARAT", "DATAPATTNS", "DCMSHRIRAM", "DEEPAKFERT",
    "DEEPAKNTR", "DELHIVERY", "DEVYANI", "DIVISLAB", "DIXON", "DLF", "DOMS", "AGARWALEYE",
    "LALPATHLAB", "DRREDDY", "ECLERX", "EICHERMOT", "EIDPARRY", "EIHOTEL", "ELECON",
    "ELGIEQUIP", "EMAMILTD", "EMCURE", "ENDURANCE", "ENGINERSIN", "ERIS", "ESCORTS",
    "ETERNAL", "EXIDEIND", "FACT", "FEDERALBNK", "FINCABLES", "FINPIPE", "FSL",
    "FIVESTAR", "FORCEMOT", "FORTIS", "NYKAA", "GMDCLTD", "GAIL", "GRSE", "GESHIP",
    "GVT&D", "GICRE", "GILLETTE", "GLAND", "GLAXO", "GLENMARK", "MEDANTA", "GMRAIRPORT",
    "GODIGIT", "GPIL", "GODFRYPHLP", "GODREJAGRO", "GODREJCP", "GODREJIND", "GODREJPROP",
    "GRANULES", "GRAPHITE", "GRASIM", "GRAVITA", "GSPL", "FLUOROCHEM", "GUJGASLTD",
    "HINDPETRO", "HUDCO", "HAPPSTMNDS", "HAVELLS", "HBLENGINE", "HCLTECH", "HDFCAMC",
    "HDFCBANK", "HDFCLIFE", "HEROMOTOCO", "HEXT", "HFCL", "HSCL", "HINDUNILVR",
    "HAL", "HINDALCO", "HINDCOPPER", "HINDZINC", "POWERINDIA", "HOMEFIRST", "HONASA",
    "HONAUT", "HYUNDAI", "IOB", "IOC", "IRCTC", "IRFC", "ICICIBANK", "ICICIGI",
    "ICICIPRULI", "IDBI", "IDFCFIRSTB", "IFCI", "IIFL", "INDGN", "INDIACEM", "INDIAMART",
    "INDIANB", "IEX", "INDHOTEL", "IREDA", "IGL", "INDUSTOWER", "INDUSINDBK", "NAUKRI",
    "INFY", "INOXINDIA", "INOXWIND", "INTELLECT", "INDIGO", "IGIL", "IKS", "IPCALAB",
    "IRB", "IRCON", "ITC", "ITCHOTELS", "ITI", "J&KBANK", "JBCHEPHARM", "JKCEMENT",
    "JBMA", "JINDALSAW", "JSL", "JINDALSTEL", "JIOFIN", "JKTYRE", "JMFINANCIL",
    "JPPOWER", "JSWENERGY", "JSWINFRA", "JSWSTEEL", "JUBLFOOD", "JUBLINGREA",
    "JUBLPHARMA", "JWL", "JYOTHYLAB", "JYOTICNC", "KEC", "KPRMILL", "KAJARIACER",
    "KPIL", "KALYANKJIL", "KARURVYSYA", "KAYNES", "KEI", "KFINTECH", "KIRLOSBROS",
    "KIRLOSENG", "KOTAKBANK", "KPITTECH", "KIMS", "KSB", "LTFOODS", "LTF", "LTTS",
    "LT", "LATENTVIEW", "LAURUSLABS", "THELEELA", "LEMONTREE", "LICHSGFIN", "LICI",
    "LINDEINDIA", "LLOYDSME", "LODHA", "LTIM", "LUPIN", "M&M", "M&MFIN", "MRPL",
    "MAHSCOOTER", "MAHSEAMLES", "MGL", "MANAPPURAM", "MANKIND", "MARICO", "MARUTI",
    "MFSL", "MAXHEALTH", "MAZDOCK", "METROPOLIS", "MINDACORP", "MMTC", "MSUMI",
    "MOTILALOFS", "MPHASIS", "MRF", "MCX", "MUTHOOTFIN", "NH", "NATCOPHARM",
    "NATIONALUM", "NAVA", "NAVINFLUOR", "NBCC", "NCC", "NESTLEIND", "NETWEB",
    "NEULANDLAB", "NIACL", "NEWGEN", "NHPC", "NAM-INDIA", "NIVABUPA", "NLCINDIA",
    "NMDC", "NSLNISP", "NTPC", "NTPCGREEN", "NUVAMA", "NUVOCO", "ONGC", "OBEROIRLTY",
    "OIL", "OLAELEC", "OLECTRA", "PAYTM", "ONESOURCE", "OFSS", "PGHH", "PIIND",
    "PAGEIND", "PATANJALI", "POLICYBZR", "PCBL", "PERSISTENT", "PETRONET", "PFIZER",
    "PGEL", "PHOENIXLTD", "PIDILITIND", "PPLPHARMA", "PNBHOUSING", "POLYMED",
    "POLYCAB", "POONAWALLA", "PFC", "POWERGRID", "PRAJIND", "PREMIERENE", "PRESTIGE",
    "PTCIL", "PNB", "PVRINOX", "RCF", "RRKABEL", "RADICO", "RVNL", "RAILTEL",
    "RAINBOW", "RKFORGE", "RBLBANK", "RECLTD", "REDINGTON", "RELIANCE", "RELINFRA",
    "RPOWER", "RHIM", "RITES", "SAIL", "SCI", "SAGILITY", "SAILIFE", "SAMMAANCAP",
    "MOTHERSON", "SAPPHIRE", "SARDAEN", "SAREGAMA", "SBFC", "SBIN", "SBICARD",
    "SBILIFE", "SCHAEFFLER", "SCHNEIDER", "SHREECEM", "SHRIRAMFIN", "SHYAMMETL",
    "SIEMENS", "ENRIN", "SIGNATURE", "SJVN", "SKFINDIA", "SOBHA", "SOLARINDS",
    "SONACOMS", "SONATSOFTW", "SRF", "STARHEALTH", "SUMICHEM", "SUNPHARMA", "SUNTV",
    "SUNDARMFIN", "SUNDRMFAST", "SUPREMEIND", "SUZLON", "SWANCORP", "SWIGGY",
    "SYNGENE", "SYRMA", "TARIL", "TATACHEM", "TATACOMM", "TATACONSUM", "TATAELXSI",
    "TATAINVEST", "TMPV", "TATAPOWER", "TATASTEEL", "TATATECH", "TTML", "TBOTEK",
    "TCS", "TECHM", "TECHNOE", "TEJASNET", "RAMCOCEM", "THERMAX", "TIMKEN",
    "TITAGARH", "TITAN", "TORNTPHARM", "TORNTPOWER", "TRENT", "TRIDENT", "TRIVENI",
    "TRITURBINE", "TIINDIA", "TVSMOTOR", "UCOBANK", "ULTRACEMCO", "UNIONBANK",
    "UBL", "UNITDSPR", "UNOMINDA", "UPL", "USHAMART", "UTIAMC", "VGUARD", "DBREALTY",
    "VTL", "VBL", "MANYAVAR", "VEDL", "VENTIVE", "VIJAYA", "VMM", "IDEA", "VOLTAS",
    "WAAREEENER", "WELCORP", "WELSPUNLIV", "WHIRLPOOL", "WIPRO", "WOCKPHARMA",
    "YESBANK", "ZEEL", "ZENTEC", "ZENSARTECH", "ZFCVINDIA", "ZYDUSLIFE"
]



start_date = "2025-04-25"
end_date = "2025-10-25"
nse_tickers = [s.strip().upper() + ".NS" if not (s.endswith(".NS") or s.endswith(".BO")) else s for s in tickers]

failed_tickers = []

for symbol in nse_tickers:
    try:
        print(f"Fetching data for: {symbol}")
        data = yf.download(symbol, start=start_date, end=end_date)

        # if yfinance returns None or empty DataFrame -> treat as failure
        if data is None or data.empty:
            print(f" -> No data found for {symbol} (empty). Skipping.")
            failed_tickers.append(symbol)
            continue

        # ensure right column order exists before renaming (defensive)
        expected_cols = ['Close','High','Low','Open','Volume']
        if not all(col in data.columns for col in expected_cols):
            # Try to select common columns if names differ, otherwise mark failed
            present = [c for c in expected_cols if c in data.columns]
            if len(present) < 5:
                print(f" -> Unexpected columns for {symbol}: {data.columns.tolist()}. Skipping.")
                failed_tickers.append(symbol)
                continue
        # At this point data contains the expected columns — rename to your single-level layout
        data = data[expected_cols]   # select in canonical order
        data.columns = ['Close', 'High', 'Low', 'Open', 'Volume']  # explicit rename (keeps same names but safe)
        data['symbol'] = symbol.replace('.NS','').replace('.BO','')

        # keep original Date index (you later reset_index / use 'index' column)
        df_all = pd.concat([df_all, data], axis=0, ignore_index=False)

    except Exception as e:
        # record failure and continue
        print(f" -> Exception for {symbol}: {e}. Skipping.")
        failed_tickers.append(symbol)
        continue

# Save failed tickers if any (so you can retry later)
save_dir = r'D:\dashboard\dashboard_project_full_data\dashboard_project_python_only\all_data'
os.makedirs(save_dir, exist_ok=True)
if failed_tickers:
    pd.DataFrame({'Failed_Tickers': failed_tickers}).to_csv(os.path.join(save_dir, 'failed_tickers.csv'), index=False)
    print(f"\nSaved failed tickers to {os.path.join(save_dir, 'failed_tickers.csv')}")

# ----- the remainder of your original processing (unchanged) -----
df_all = df_all.sort_index().reset_index()
df_all = df_all.sort_values(['symbol', 'index'], ascending=[True, True]).reset_index(drop=True)
df_all['Day_Change'] = df_all.groupby('symbol')['Close'].diff()
df_all['Day_Change_%'] = df_all.groupby('symbol')['Close'].pct_change().mul(100).round(2)
df_all = df_all.sort_values(['symbol', 'index'], ascending=[True, False]).reset_index(drop=True)
df_all['Date'] = df_all['index']
df_all['Date'] = pd.to_datetime(df_all['Date'])

# resample weekly per symbol, taking last close of each week
weekly = (
    df_all.set_index('Date')
    .groupby('symbol')['Close']
    .resample('W-FRI')
    .last()
    .reset_index()
)

# compute weekly percentage change
weekly['Weekly_Return_%'] = weekly.groupby('symbol')['Close'].pct_change().mul(100).round(2)
weekly = weekly.sort_values(['symbol', 'Date'], ascending=[True, False]).reset_index(drop=True)
# Ensure date column is datetime
df_all['Date'] = pd.to_datetime(df_all['Date'])

# Resample monthly per symbol (take last close of each month)
monthly = (
    df_all.set_index('Date')
    .groupby('symbol')['Close']
    .resample('M')     # 'M' = month-end frequency
    .last()
    .reset_index()
)

# Compute month-over-month percentage change
monthly['Monthly_Return_%'] = (
    monthly.groupby('symbol')['Close']
    .pct_change()
    .mul(100)
    .round(2)
)

# Optional: Add formatted string column for display (like +5.62%)
monthly['Monthly_Return_Str'] = monthly['Monthly_Return_%'].apply(
    lambda x: f"{x:+.2f}%" if pd.notna(x) else ""
)

monthly = monthly.sort_values(['symbol', 'Date'], ascending=[True, False]).reset_index(drop=True)

summary_df1 = (
    df_all.groupby('symbol')['Day_Change_%']
    .apply(lambda x: list(x.head(10)))
    .reset_index(name='5D_Change')
)

summary_df2 = (
    weekly.groupby('symbol')['Weekly_Return_%']
    .apply(lambda x: list(x.head(5)))
    .reset_index(name='5W_Change')
)
summary_df3 = (
    monthly.groupby('symbol')['Monthly_Return_%']
    .apply(lambda x: list(x.head(5)))
    .reset_index(name='5M_Change')
)

summary_df = summary_df1.merge(summary_df2, on='symbol').merge(summary_df3, on='symbol')

def replace_nan_in_list(x):
    if isinstance(x, list):
        return [0 if (pd.isna(v) or v == np.nan) else v for v in x]
    return x

# Apply replacement to each column
for col in ["5D_Change", "5W_Change", "5M_Change"]:
    summary_df[col] = summary_df[col].apply(replace_nan_in_list)
summary_df.to_csv(os.path.join(save_dir, 'day_week_month_summery.csv'), index=False)
print(f"Saved summary to {os.path.join(save_dir, 'day_week_month_summery.csv')}")
# Out:
# Fetching data for: 360ONE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: 3MINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ABB.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ABLBL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ABREL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AADHARHFC.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AARTIIND.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AAVAS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ABBOTINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ACC.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ACMESOLAR.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ACE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ADANIENSOL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ADANIENT.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ADANIGREEN.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ADANIPORTS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ADANIPOWER.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ATGL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ABSLAMC.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ABFRL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ABCAPITAL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AEGISLOG.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AEGISVOPAK.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AFCONS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AFFLE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AIAENG.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AJANTPHARM.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AKUMS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AKZOINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: APLLTD.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ALKEM.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ALKYLAMINE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ALOKINDS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ARE&M.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AMBER.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AMBUJACEM.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ANANDRATHI.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ANANTRAJ.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ANGELONE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: APARINDS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: APLAPOLLO.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: APOLLOHOSP.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: APOLLOTYRE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: APTUS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ASAHIINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ASHOKLEY.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ASIANPAINT.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ASTERDM.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ASTRAL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ATHERENERG.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ATUL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AUBANK.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AUROPHARMA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AIIL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: DMART.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AWL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: AXISBANK.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BHEL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BPCL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BAJAJ-AUTO.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BAJFINANCE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BAJAJFINSV.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BAJAJHLDNG.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BAJAJHFL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BALKRISIND.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BALRAMCHIN.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BANDHANBNK.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BANKBARODA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BANKINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: MAHABANK.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BASF.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BATAINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BAYERCROP.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BEML.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BERGEPAINT.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BDL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BEL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BHARATFORG.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BHARTIARTL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BHARTIHEXA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BIKAJI.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BIOCON.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BSOFT.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BLS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BLUEDART.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BLUEJET.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BLUESTARCO.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BBTC.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BOSCHLTD.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: FIRSTCRY.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BRIGADE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BRITANNIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: BSE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CDSL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CHENNPETRO.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: MAPMYINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CAMPUS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CAMS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CANFINHOME.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CANBK.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CAPLIPOINT.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CGCL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CARBORUNIV.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CASTROLIND.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CCL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CEATLTD.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CENTRALBK.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CENTURYPLY.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CERA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CESC.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CGPOWER.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CHALET.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CHAMBLFERT.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CHOICEIN.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CHOLAHLDNG.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CHOLAFIN.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CIPLA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CUB.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CLEAN.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: COALINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: COCHINSHIP.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: COFORGE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: COHANCE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: COLPAL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CONCORDBIO.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: CONCOR.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: COROMANDEL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for:
NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: VEDL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: VENTIVE.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: VIJAYA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: VMM.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: IDEA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: VOLTAS.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: WAAREEENER.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: WELCORP.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: WELSPUNLIV.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: WHIRLPOOL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: WIPRO.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: WOCKPHARMA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: YESBANK.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ZEEL.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ZENTEC.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ZENSARTECH.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ZFCVINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# Fetching data for: ZYDUSLIFE.NS
# [*********************100%***********************]  1 of 1 completed
# Saved summary to D:\dashboard\dashboard_project_full_data\dashboard_project_python_only\all_data\day_week_month_summery.csv

# %%
cols_to_drop = [
    '5M_Change_Positive', '5M_Change_Negative',
    '5D_Change_Pos_Sum', '5D_Change_Neg_Sum_Abs', '5D_Change_Pos_Pct', '5D_Change_Neg_Pct',
    '5W_Change_Pos_Sum', '5W_Change_Neg_Sum_Abs', '5W_Change_Pos_Pct', '5W_Change_Neg_Pct',
    '5M_Change_Pos_Sum', '5M_Change_Neg_Sum_Abs', '5M_Change_Pos_Pct', '5M_Change_Neg_Pct'
]

# Drop them from DataFrame (ignore if some columns don’t exist)
summary_df = summary_df.drop(columns=cols_to_drop, errors='ignore')

# %%
summary_df.columns
# Out:
# Index(['symbol', '5D_Change', '5W_Change', '5M_Change'], dtype='object')

# %%
def count_pos_neg(values):
    pos = sum(1 for v in values if v > 0)
    neg = sum(1 for v in values if v < 0)
    return pd.Series({'Positive': pos, 'Negative': neg})

# Apply function to each change column
for col in ['5D_Change', '5W_Change', '5M_Change']:
    counts = summary_df[col].apply(count_pos_neg)
    summary_df[f'{col}_Positive'] = counts['Positive']
    summary_df[f'{col}_Negative'] = counts['Negative']

# %%
summary_df
# Out:
#          symbol                                          5D_Change  \
# 0        360ONE  [0.58, 0.3, -0.67, 1.58, -0.59, 0.98, 2.99, 2....
# 1       3MINDIA  [0.0, -0.18, 0.39, 0.37, 0.58, 0.31, 0.7, 0.59...
# 2     AADHARHFC  [2.78, -1.4, 0.37, 2.0, -0.87, -0.49, -1.09, 0...
# 3      AARTIIND  [0.63, 1.12, 0.66, -0.57, -0.46, 1.28, -0.85, ...
# 4         AAVAS  [1.19, 2.94, 0.02, 0.9, -0.11, 1.28, -0.61, -1...
# ..          ...                                                ...
# 493        ZEEL  [-0.91, 1.17, 0.55, -1.36, -3.6, -0.55, 0.7, -...
# 494  ZENSARTECH  [0.49, 2.72, -0.23, -0.13, 1.0, 2.47, 0.07, -2...
# 495      ZENTEC  [0.73, -0.99, 1.97, -0.25, 1.99, -1.29, 0.35, ...
# 496   ZFCVINDIA  [-0.85, -0.64, 0.37, 0.26, -0.38, 0.16, -0.3, ...
# 497   ZYDUSLIFE  [-0.41, 0.95, -0.28, 1.49, 0.31, 0.75, -0.2, -...
#
#                               5W_Change                            5M_Change  \
# 0       [1.79, 6.37, 4.37, 4.73, -7.31]  [15.79, 0.58, -3.29, -11.87, 19.76]
# 1     [0.58, -0.08, 1.56, -0.05, -2.56]     [0.98, -4.28, 0.02, 9.77, -2.65]
# 2     [3.75, -2.29, 1.09, -0.37, -5.06]     [2.42, 1.45, -0.81, 11.54, 2.33]
# 3      [1.84, -0.85, -0.68, 1.6, -4.73]  [1.81, -0.32, -10.22, -12.39, 2.17]
# 4     [5.12, -1.59, -1.82, 5.54, -5.73]  [3.31, 7.48, -11.84, -17.59, 13.51]
# ..                                  ...                                  ...
# 493  [-0.57, -5.43, -2.18, 1.16, -3.31]  [-6.76, -3.16, 0.24, -19.19, 12.14]
# 494    [2.85, -2.0, 5.06, -1.83, -9.72]    [5.49, -0.65, -4.72, -3.06, 1.14]
# 495  [1.45, -2.99, -4.61, -0.89, -6.45]  [-2.53, -1.84, -0.17, -26.1, -7.41]
# 496  [-0.86, -2.48, -1.75, 7.86, -4.98]    [-0.12, -8.31, 6.89, -1.54, 0.18]
# 497    [1.75, -0.58, 0.52, 1.36, -6.01]      [2.34, 0.09, 1.16, -0.91, 6.45]
#
#      5D_Change_Positive  5D_Change_Negative  5W_Change_Positive  \
# 0                     8                   2                   4
# 1                     7                   2                   2
# 2                     5                   5                   2
# 3                     5                   5                   2
# 4                     6                   4                   2
# ..                  ...                 ...                 ...
# 493                   4                   6                   1
# 494                   6                   4                   2
# 495                   5                   5                   1
# 496                   3                   7                   1
# 497                   5                   5                   3
#
#      5W_Change_Negative  5M_Change_Positive  5M_Change_Negative
# 0                     1                   3                   2
# 1                     3                   3                   2
# 2                     3                   4                   1
# 3                     3                   2                   3
# 4                     3                   3                   2
# ..                  ...                 ...                 ...
# 493                   4                   2                   3
# 494                   3                   2                   3
# 495                   4                   0                   5
# 496                   4                   2                   3
# 497                   2                   4                   1
#
# [498 rows x 10 columns]

# %%
def pos_pct(values):
    # compute sum of positives and sum of absolute negatives
    pos_sum = sum(v for v in values if v is not None and v > 0)
    neg_sum_abs = sum(abs(v) for v in values if v is not None and v < 0)
    total = pos_sum + neg_sum_abs
    if total == 0:
        return 0.0
    return round((total), 2)

# Create single percentage columns for each period
summary_df['5D_Pos_Pct'] = summary_df['5D_Change'].apply(pos_pct)
summary_df['5W_Pos_Pct'] = summary_df['5W_Change'].apply(pos_pct)
summary_df['5M_Pos_Pct'] = summary_df['5M_Change'].apply(pos_pct)

# %%
summary_df.to_csv(os.path.join(save_dir, 'day_week_month_summery.csv'), index=False)

# %%
summary_df.to_csv(os.path.join(save_dir, 'day_week_month_summery.csv'), index=False)

# %%
from flask import Flask, jsonify
import pandas as pd

app = Flask(__name__)

path = r"D:\dashboard\dashboard_project_full_data\dashboard_project_python_only\all_data\day_week_month_summery.csv"

@app.route("/api/summary", methods=["GET"])
def get_summary():
    try:
        df = pd.read_csv(path)
        data = df.to_dict(orient='records')
        return jsonify({"summary": data, "status": "success"})
    except Exception as e:
        return jsonify({"error": str(e), "status": "failed"}), 500


if __name__ == "__main__":
    app.run(debug=True, port=4000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:4000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
import pandas as pd
url = "https://economictimes.indiatimes.com/markets/fii-dii-activity"
tables = pd.read_html(url)
df = pd.concat([tables[3], tables[4]], axis=1).dropna(axis=1, how='all').reset_index(drop=True)
df
# Out:
#       Date  Nifty Closing Nifty Closing.1  FII Cash (Cr.)  DII Cash (Cr.)  \
# 0   23 Oct       25891.40         (0.09%)        -1165.94         3893.73
# 1   21 Oct       25868.60         (0.10%)           96.72         -607.01
# 2   20 Oct       25843.15         (0.52%)          790.45         2485.46
# 3   17 Oct       25709.85         (0.49%)          308.98         1526.61
# 4   16 Oct       25585.30         (1.03%)          997.29         4076.20
# 5   15 Oct       25323.55         (0.71%)           68.64         4650.08
# 6   14 Oct       25145.50        (-0.32%)        -1508.53         3661.13
# 7   13 Oct       25227.35        (-0.23%)         -240.10         2333.42
# 8   10 Oct       25285.35         (0.41%)          459.20         1707.83
# 9   09 Oct       25181.80         (0.54%)         1308.16          864.36
# 10  08 Oct       25046.15        (-0.25%)           81.28          329.96
# 11  07 Oct       25108.30         (0.12%)         1440.66          452.57
# ...

# %%
import sys, subprocess

subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "fastapi", "uvicorn"])
# Out:
# 0

# %%
url = "https://economictimes.indiatimes.com/markets/fii-dii-activity/fii-cash"
tables = pd.read_html(url)

# %%
tables[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 tables[4]
#
# IndexError: list index out of range

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 tables[4]
#
# IndexError: list index out of range

# %%
tables[4]
# Out:
#     FII Cash (Cr.)  FII Cash (Cr.).1  DII Cash (Cr.)  DII Cash (Cr.).1  \
# 0            96.72               NaN         -607.01               NaN
# 1           790.45               NaN         2485.46               NaN
# 2           308.98               NaN         1526.61               NaN
# 3           997.29               NaN         4076.20               NaN
# 4            68.64               NaN         4650.08               NaN
# 5         -1508.53               NaN         3661.13               NaN
# 6          -240.10               NaN         2333.42               NaN
# 7           459.20               NaN         1707.83               NaN
# 8          1308.16               NaN          864.36               NaN
# 9            81.28               NaN          329.96               NaN
# 10         1440.66               NaN          452.57               NaN
# 11         -313.77               NaN         5036.39               NaN
# ...

# %%
tables[3]
# Out:
#       Date  Nifty Closing Nifty Closing.1
# 0   21 Oct       25868.60         (0.10%)
# 1   20 Oct       25843.15         (0.52%)
# 2   17 Oct       25709.85         (0.49%)
# 3   16 Oct       25585.30         (1.03%)
# 4   15 Oct       25323.55         (0.71%)
# 5   14 Oct       25145.50        (-0.32%)
# 6   13 Oct       25227.35        (-0.23%)
# 7   10 Oct       25285.35         (0.41%)
# 8   09 Oct       25181.80         (0.54%)
# 9   08 Oct       25046.15        (-0.25%)
# 10  07 Oct       25108.30         (0.12%)
# 11  06 Oct       25077.65         (0.74%)
# 12  03 Oct       24894.25         (0.23%)
# 13  01 Oct       24836.30         (0.92%)
# 14  30 Sep       24611.10        (-0.10%)
# 15  29 Sep       24634.90        (-0.08%)
# 16  26 Sep       24654.70        (-0.95%)
# 17  25 Sep       24890.85         (0.00%)
# 18  24 Sep       24890.85        (-1.11%)
# 19  23 Sep       25169.50        (-0.13%)
# 20  22 Sep       25202.35        (-0.49%)
# ...

# %%
tables[4]
# Out:
#     FII Cash (Cr.)  FII Cash (Cr.).1  DII Cash (Cr.)  DII Cash (Cr.).1  \
# 0            96.72               NaN         -607.01               NaN
# 1           790.45               NaN         2485.46               NaN
# 2           308.98               NaN         1526.61               NaN
# 3           997.29               NaN         4076.20               NaN
# 4            68.64               NaN         4650.08               NaN
# 5         -1508.53               NaN         3661.13               NaN
# 6          -240.10               NaN         2333.42               NaN
# 7           459.20               NaN         1707.83               NaN
# 8          1308.16               NaN          864.36               NaN
# 9            81.28               NaN          329.96               NaN
# 10         1440.66               NaN          452.57               NaN
# 11         -313.77               NaN         5036.39               NaN
# ...

# %%
df_et.columns
# Out:
# MultiIndex([(        'Date',                  'Date'),
#             ('Equity (Cr.)',      'Gross Equity Buy'),
#             ('Equity (Cr.)',     'Gross Equity Sell'),
#             ('Equity (Cr.)',   'Net Equity Buy/Sell'),
#             ('Equity (Cr.)', 'Net Equity Buy/Sell.1'),
#             (  'Debt (Cr.)',        'Gross Debt Buy'),
#             (  'Debt (Cr.)',       'Gross Debt Sell'),
#             (  'Debt (Cr.)',     'Net Debt Buy/Sell'),
#             (  'Debt (Cr.)',   'Net Debt Buy/Sell.1')],
#            )

# %%
tables[3]
# Out:
#             Date     Equity (Cr.)                                        \
#             Date Gross Equity Buy Gross Equity Sell Net Equity Buy/Sell
# 0   Last 30 Days         230872.2         -248839.2            -17967.1
# 1        2 weeks          84836.1          -83863.4               972.7
# 2         1 week          26914.0          -25717.9              1196.2
# 3         21 Oct            622.4            -525.7                96.8
# 4         20 Oct          11786.4          -10995.9               790.5
# 5         17 Oct          14505.3          -14196.3               309.0
# 6         16 Oct          14739.2          -13741.9               997.3
# 7         15 Oct          14013.6          -13944.9                68.7
# 8         14 Oct          10847.9          -12356.4             -1508.6
# 9         13 Oct           8085.5           -8325.6              -240.1
# 10        10 Oct          10236.1           -9776.9               459.2
# ...

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# Ask the user for the stock symbol (e.g., 'AAPL' for Apple, 'TCS.NS' for TCS India)
symbol = "T"

# Fetch historical data (last 1 year by default)
data = yf.download(symbol, period="1w")

# # Display first few rows
# print("\n📊 Historical Data:")
# print(data.head())

# # Plot the closing price
# plt.figure(figsize=(10, 5))
# plt.plot(data['Close'], label=f"{symbol} Closing Price")
# plt.title(f"{symbol} - 1 Year Historical Price")
# plt.xlabel("Date")
# plt.ylabel("Price (₹ or $)")
# plt.legend()
# plt.grid(True)
# plt.show()
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_23316\398128000.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, period="1w")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TCS']: YFPricesMissingError('possibly delisted; no price data found  (period=1w) (Yahoo error = "No data found, symbol may be delisted")')

# %%
symbol = "066570.KS"

# Fetch last 1 year of data
data = yf.download(symbol, period="1y")

# Check if data is empty
if data.empty:
    print(f"⚠️ No data found for {symbol}. Try another symbol or check suffix (.NS or .BO).")
else:
    print(data.head())
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_23316\537659594.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, period="1y")
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open    Volume
# Ticker         066570.KS     066570.KS     066570.KS     066570.KS 066570.KS
# Date
# 2024-10-24  95982.039062  98253.218999  95488.304294  98253.218999    295597
# 2024-10-25  90945.945312  96179.533914  90550.957494  96179.533914   1000018
# 2024-10-28  91242.179688  91637.167478  90353.457158  91439.673583    490122
# 2024-10-29  90254.718750  91735.923106  90057.224836  91637.176149    473930
# 2024-10-30  90353.460938  91242.183504  90353.460938  90550.954841    295828

# %%
data
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker         066570.KS     066570.KS     066570.KS     066570.KS 066570.KS
# Date
# 2024-10-24  95982.039062  98253.218999  95488.304294  98253.218999    295597
# 2024-10-25  90945.945312  96179.533914  90550.957494  96179.533914   1000018
# 2024-10-28  91242.179688  91637.167478  90353.457158  91439.673583    490122
# 2024-10-29  90254.718750  91735.923106  90057.224836  91637.176149    473930
# 2024-10-30  90353.460938  91242.183504  90353.460938  90550.954841    295828
# ...                  ...           ...           ...           ...       ...
# 2025-10-20  91000.000000  91400.000000  85700.000000  85800.000000   2111530
# 2025-10-21  89200.000000  91900.000000  88600.000000  91400.000000   1062670
# 2025-10-22  89600.000000  90100.000000  87600.000000  90000.000000    605113
# 2025-10-23  90200.000000  91200.000000  88300.000000  88600.000000    756369
# ...

# %%
symbol = "LGEINDIA.NS"  # or whatever ticker Yahoo uses for NSE listing
data = yf.download(symbol, period="6mo", interval="1d")

if data.empty:
    print(f"No data found for {symbol}.")
else:
    print(data.head())
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_23316\3942609861.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, period="6mo", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker      LGEINDIA.NS  LGEINDIA.NS  LGEINDIA.NS  LGEINDIA.NS LGEINDIA.NS
# Date
# 2025-10-14  1689.900024  1749.000000  1650.000000  1710.099976    68793750
# 2025-10-15  1688.099976  1728.900024  1680.199951  1698.000000     9113558
# 2025-10-16  1671.300049  1705.000000  1662.000000  1688.900024     4216934
# 2025-10-17  1668.000000  1701.300049  1627.800049  1675.000000     4992719
# 2025-10-20  1665.199951  1686.400024  1645.000000  1673.400024     2466878

# %%
# combined_nse_6month.py
import yfinance as yf
import pandas as pd
from tqdm import tqdm
from pathlib import Path
import time

tickers = [
    "ADANIENT","ADANIPORTS","APOLLOHOSP","ASIANPAINT","AXISBANK","BAJAJ-AUTO","BAJFINANCE",
    "BAJAJFINSV","BEL","BHARTIARTL","CIPLA","COALINDIA","DRREDDY","EICHERMOT","ETERNAL",
    "GRASIM","HCLTECH","HDFCBANK","HDFCLIFE","HINDUNILVR","HINDALCO","ICICIBANK","INFY",
    "INDIGO","ITC","JIOFIN","JSWSTEEL","KOTAKBANK","LT","M&M","MARUTI","MAXHEALTH",
    "NESTLEIND","NTPC","ONGC","POWERGRID","RELIANCE","SBIN","SBILIFE","SHRIRAMFIN",
    "SUNPHARMA","TATACONSUM","TATAMOTORS","TATASTEEL","TCS","TECHM","TITAN","TRENT",
    "ULTRACEMCO","WIPRO"
]
ysym = symbol.strip().upper()
    if not (ysym.endswith(".NS") or ysym.endswith(".BO")):
        ysym = ysym + ".NS"






OUTPUT_DIR = Path("nse_6month_data")
OUTPUT_DIR.mkdir(exist_ok=True)
OUTFILE = OUTPUT_DIR / "nse_6month_all.csv"

PERIOD = "6mo"
INTERVAL = "1d"
MAX_RETRIES = 3
SLEEP = 1.0  # seconds

def fetch_symbol(symbol):
    ysym = symbol.strip().upper()
    if not (ysym.endswith(".NS") or ysym.endswith(".BO")):
        ysym = ysym + ".NS"
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            df = yf.download(ysym, period=PERIOD, interval=INTERVAL, progress=False)
            if df is None or df.empty:
                print(f"[WARN] No data for {ysym} (attempt {attempt})")
            else:
                # ensure Date is column
                df = df.reset_index()
                # standardize column names
                df = df.rename(columns={
                    "Open":"Open","High":"High","Low":"Low","Close":"Close",
                    "Adj Close":"Adj Close","Volume":"Volume"
                })
                # keep only necessary columns
                cols_keep = ['Date','Open','High','Low','Close','Adj Close','Volume']
                df = df[[c for c in cols_keep if c in df.columns]]
                # add Symbol column (without .NS)
                df['Symbol'] = ysym.replace('.NS','').replace('.BO','')
                return df
        except Exception as e:
            print(f"[ERR] {ysym} attempt {attempt} error: {e}")
        time.sleep(SLEEP * attempt)
    print(f"[SKIP] Skipping {symbol} after {MAX_RETRIES} attempts.")
    return None

def main():
    all_dfs = []
    for sym in tqdm(tickers, desc="Downloading"):
        df = fetch_symbol(sym)
        if df is not None:
            all_dfs.append(df)
    if not all_dfs:
        print("No data collected for any symbol.")
        return

    combined = pd.concat(all_dfs, ignore_index=True)
    # Ensure Date is datetime and sort
    combined['Date'] = pd.to_datetime(combined['Date'])
    combined = combined.sort_values(['Date','Symbol']).reset_index(drop=True)

    # Save long-format CSV
    combined.to_csv(OUTFILE, index=False)
    print(f"\n✅ Saved combined CSV: {OUTFILE.resolve()}")
    print(f"Rows: {len(combined)}, Columns: {list(combined.columns)}")

    # OPTIONAL: also save a pivoted Adjusted Close wide-format file
    try:
        wide = combined.pivot_table(index='Date', columns='Symbol', values='Adj Close')
        wide_file = OUTPUT_DIR / "nse_6month_adjclose_wide.csv"
        wide.to_csv(wide_file)
        print(f"✅ Saved wide Adj Close CSV: {wide_file.resolve()}")
    except Exception as e:
        print(f"[WARN] Could not create wide Adj Close CSV: {e}")

if __name__ == "__main__":
    main()
# Out:
# Downloading:   0%|          | 0/50 [00:00<?, ?it/s]C:\Users\deepa\AppData\Local\Temp\ipykernel_31464\1215176691.py:33: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ysym, period=PERIOD, interval=INTERVAL, progress=False)
# Downloading:   2%|▏         | 1/50 [00:01<01:20,  1.64s/it]C:\Users\deepa\AppData\Local\Temp\ipykernel_31464\1215176691.py:33: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ysym, period=PERIOD, interval=INTERVAL, progress=False)
# Downloading:   4%|▍         | 2/50 [00:02<00:45,  1.05it/s]C:\Users\deepa\AppData\Local\Temp\ipykernel_31464\1215176691.py:33: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ysym, period=PERIOD, interval=INTERVAL, progress=False)
# ...

# %%
for sym in tqdm(tickers, desc="Downloading"):
df = fetch_symbol(sym)

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
cols = [
    ('Close', ),
    ('High',  ),
    ('Low',   ),
    ('Open',  ),
    ('Volume',),
]

mi = pd.MultiIndex.from_tuples(cols)
df_empty = pd.DataFrame(columns=mi)
df_empty.index = pd.DatetimeIndex([], name='Date')
tickers = [
    "ADANIENT","ADANIPORTS","APOLLOHOSP","ASIANPAINT","AXISBANK","BAJAJ-AUTO","BAJFINANCE",
    "BAJAJFINSV","BEL","BHARTIARTL","CIPLA","COALINDIA","DRREDDY","EICHERMOT","ETERNAL",
    "GRASIM","HCLTECH","HDFCBANK","HDFCLIFE","HINDUNILVR","HINDALCO","ICICIBANK","INFY",
    "INDIGO","ITC","JIOFIN","JSWSTEEL","KOTAKBANK","LT","M&M","MARUTI","MAXHEALTH",
    "NESTLEIND","NTPC","ONGC","POWERGRID","RELIANCE","SBIN","SBILIFE","SHRIRAMFIN",
    "SUNPHARMA","TATACONSUM","TATAMOTORS","TATASTEEL","TCS","TECHM","TITAN","TRENT",
    "ULTRACEMCO","WIPRO"
]
nse_tickers = [s.strip().upper() + ".NS" if not (s.endswith(".NS") or s.endswith(".BO")) else s for s in tickers]
for symbol in nse_tickers:
    data = yf.download(symbol, period="1w", interval="1d")
    # The .append method is deprecated; use pd.concat instead.
    df_empty = pd.concat([df_empty, data], ignore_index=False)
df_empty
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_36848\2058234215.py:26: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, period="1w", interval="1d")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADANIENT.NS']: YFInvalidPeriodError("ADANIENT.NS: Period '1w' is invalid, must be one of: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max")
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 28
#      26     data = yf.download(symbol, period="1w", interval="1d")
#      27     # The .append method is deprecated; use pd.concat instead.
# ---> 28     df_empty = pd.concat([df_empty, data], ignore_index=False)
#      29 df_empty
#
# ...

# %%
import yfinance as yf
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# desired single-level columns (yfinance standard)
desired_cols = ['symbol','Close', 'High', 'Low', 'Open', 'Volume']
df_all = pd.DataFrame(columns=desired_cols)
tickers = [
    "ADANIENT",
    "ADANIPORTS",
    "APOLLOHOSP","ASIANPAINT","AXISBANK","BAJAJ-AUTO","BAJFINANCE",
    "BAJAJFINSV","BEL","BHARTIARTL","CIPLA","COALINDIA","DRREDDY","EICHERMOT","ETERNAL",
    "GRASIM","HCLTECH","HDFCBANK","HDFCLIFE","HINDUNILVR","HINDALCO","ICICIBANK","INFY",
    "INDIGO","ITC","JIOFIN","JSWSTEEL","KOTAKBANK","LT","M&M","MARUTI","MAXHEALTH",
    "NESTLEIND","NTPC","ONGC","POWERGRID","RELIANCE","SBIN","SBILIFE","SHRIRAMFIN",
    "SUNPHARMA","TATACONSUM","TATAMOTORS","TATASTEEL","TCS","TECHM","TITAN","TRENT",
    "ULTRACEMCO","WIPRO"
]
start_date = "2024-10-01"
end_date = "2024-10-26"
nse_tickers = [s.strip().upper() + ".NS" if not (s.endswith(".NS") or s.endswith(".BO")) else s for s in tickers]
for symbol in nse_tickers:
    # data = yf.download(symbol, period="1mo")
    data = yf.download(symbol, start=start_date, end=end_date)
    data.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
    data['symbol'] = symbol.replace('.NS','').replace('.BO','')
    df_all = pd.concat([df_all, data], axis=0, ignore_index=False)
df_all = df_all.sort_index().reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df_all
# Out:
#          index      symbol        Close         High          Low  \
# 0   2024-10-01    ADANIENT  3184.471924  3190.368811  3105.412248
# 1   2024-10-01   MAXHEALTH   969.081726   987.560402   964.237280
# 2   2024-10-01     HCLTECH  1738.566772  1744.261453  1713.203701
# 3   2024-10-01   NESTLEIND  1339.281250  1340.740704  1322.385866
# 4   2024-10-01  BAJAJFINSV  1974.288086  2006.122551  1968.091154
# ..         ...         ...          ...          ...          ...
# 895 2024-10-25   KOTAKBANK  1766.812988  1784.442687  1754.976659
# 896 2024-10-25    JSWSTEEL   941.315186   957.371984   924.310987
# 897 2024-10-25      JIOFIN   310.715485   317.355125   305.523569
# 898 2024-10-25        ONGC   251.377136   257.327173   249.044739
# 899 2024-10-25       WIPRO   261.291321   265.402164   259.872952
#
#             Open    Volume
# 0    3134.697324   1367116
# 1     985.362926   1331140
# 2    1713.203701   1642542
# 3    1330.845938   1105518
# 4    1972.039182   1326900
# ...

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
import yfinance as yf
import pandas as pd
import warnings

# suppress warnings & progress bars
warnings.filterwarnings("ignore")

# ---------------------
# 🎯 Customize date range here
# ---------------------
start_date = "2024-10-01"
end_date = "2024-10-26"
# Or dynamically:
# from datetime import datetime, timedelta
# end_date = datetime.today().strftime('%Y-%m-%d')
# start_date = (datetime.today() - timedelta(days=180)).strftime('%Y-%m-%d')

tickers = [
    "ADANIENT","ADANIPORTS","APOLLOHOSP","ASIANPAINT","AXISBANK","BAJAJ-AUTO","BAJFINANCE",
    "BAJAJFINSV","BEL","BHARTIARTL","CIPLA","COALINDIA","DRREDDY","EICHERMOT","ETERNAL",
    "GRASIM","HCLTECH","HDFCBANK","HDFCLIFE","HINDUNILVR","HINDALCO","ICICIBANK","INFY",
    "INDIGO","ITC","JIOFIN","JSWSTEEL","KOTAKBANK","LT","M&M","MARUTI","MAXHEALTH",
    "NESTLEIND","NTPC","ONGC","POWERGRID","RELIANCE","SBIN","SBILIFE","SHRIRAMFIN",
    "SUNPHARMA","TATACONSUM","TATAMOTORS","TATASTEEL","TCS","TECHM","TITAN","TRENT",
    "ULTRACEMCO","WIPRO"
]

# Add NSE suffix
nse_tickers = [s.strip().upper() + ".NS" if not (s.endswith(".NS") or s.endswith(".BO")) else s for s in tickers]

# Create empty DataFrame
df_all = pd.DataFrame()

# Loop through tickers
for symbol in nse_tickers:
    try:
        # ⏳ Download data for your custom date range
        data = yf.download(symbol, start=start_date, end=end_date, progress=False, auto_adjust=False)

        if data is None or data.empty:
            print(f"[SKIP] No data found for {symbol}")
            continue

        # Select and rename columns (match your desired structure)
        data = data[['Close', 'High', 'Low', 'Open', 'Volume']].copy()

        # Add Symbol and Date columns
        data['Symbol'] = symbol.replace('.NS','').replace('.BO','')
        data['Date'] = data.index

        # Append cleanly
        df_all = pd.concat([df_all, data], axis=0, ignore_index=True)

    except Exception as e:
        print(f"[ERR] Skipping {symbol}: {e}")

# Sort by Date, Symbol
df_all = df_all.sort_values(['Date','Symbol']).reset_index(drop=True)

# Show summary
print(f"✅ Download complete! {len(df_all)} rows collected from {start_date} to {end_date}.")
print(df_all.head(10))
# Out:
# ✅ Download complete! 900 rows collected from 2024-10-01 to 2024-10-26.
# Price         Close        High         Low         Open      Volume  \
# Ticker  ADANIENT.NS ADANIENT.NS ADANIENT.NS  ADANIENT.NS ADANIENT.NS
# 0       3186.100098      3192.0      3107.0  3136.300049   1367116.0
# 1               NaN         NaN         NaN          NaN         NaN
# 2               NaN         NaN         NaN          NaN         NaN
# 3               NaN         NaN         NaN          NaN         NaN
# 4               NaN         NaN         NaN          NaN         NaN
# 5               NaN         NaN         NaN          NaN         NaN
# 6               NaN         NaN         NaN          NaN         NaN
# 7               NaN         NaN         NaN          NaN         NaN
# 8               NaN         NaN         NaN          NaN         NaN
# 9               NaN         NaN         NaN          NaN         NaN
#
# ...

# %%
data = yf.download("ADANIENT.NS", period="1mo")
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_36848\3725407968.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("ADANIENT.NS", period="1mo")
# [*********************100%***********************]  1 of 1 completed

# %%
data.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
data
# Out:
#                   Close         High          Low         Open   Volume
# Date
# 2025-09-24  2619.800049  2676.000000  2614.399902  2655.000000  1720785
# 2025-09-25  2576.399902  2647.899902  2567.000000  2625.000000  1489682
# 2025-09-26  2543.699951  2605.000000  2535.000000  2572.800049  1037808
# 2025-09-29  2509.500000  2555.000000  2505.000000  2543.699951  1012402
# 2025-09-30  2505.899902  2535.000000  2490.600098  2522.000000   712592
# 2025-10-01  2592.699951  2603.399902  2472.100098  2518.399902  1573485
# 2025-10-03  2589.899902  2612.899902  2564.399902  2595.000000   917651
# 2025-10-06  2573.500000  2599.800049  2562.600098  2589.100098   654955
# 2025-10-07  2542.199951  2617.300049  2533.100098  2580.699951  1120230
# 2025-10-08  2524.100098  2565.000000  2500.000000  2562.000000  1063357
# 2025-10-09  2542.399902  2559.000000  2522.199951  2535.000000   651703
# 2025-10-10  2550.899902  2565.000000  2538.800049  2552.000000   690142
# ...

# %%
df_all
# Out:
#         index         symbol  (Close, ADANIENT.NS)  (High, ADANIENT.NS)  \
# 0  2025-09-24  ADANIPORTS.NS           2619.800049          2676.000000
# 1  2025-09-24            NaN                   NaN                  NaN
# 2  2025-09-25  ADANIPORTS.NS           2576.399902          2647.899902
# 3  2025-09-25            NaN                   NaN                  NaN
# 4  2025-09-26  ADANIPORTS.NS           2543.699951          2605.000000
# 5  2025-09-26            NaN                   NaN                  NaN
# 6  2025-09-29  ADANIPORTS.NS           2509.500000          2555.000000
# 7  2025-09-29            NaN                   NaN                  NaN
# 8  2025-09-30  ADANIPORTS.NS           2505.899902          2535.000000
# 9  2025-09-30            NaN                   NaN                  NaN
# 10 2025-10-01  ADANIPORTS.NS           2592.699951          2603.399902
# 11 2025-10-01            NaN                   NaN                  NaN
# ...

# %%
df_all
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
data.columns
# Out:
# MultiIndex([( 'Close', 'HINDUNILVR.NS'),
#             (  'High', 'HINDUNILVR.NS'),
#             (   'Low', 'HINDUNILVR.NS'),
#             (  'Open', 'HINDUNILVR.NS'),
#             ('Volume', 'HINDUNILVR.NS')],
#            names=['Price', 'Ticker'])

# %%
tickers = [
    "ADANIENT","ADANIPORTS","APOLLOHOSP","ASIANPAINT","AXISBANK","BAJAJ-AUTO","BAJFINANCE",
    "BAJAJFINSV","BEL","BHARTIARTL","CIPLA","COALINDIA","DRREDDY","EICHERMOT","ETERNAL",
    "GRASIM","HCLTECH","HDFCBANK","HDFCLIFE","HINDUNILVR","HINDALCO","ICICIBANK","INFY",
    "INDIGO","ITC","JIOFIN","JSWSTEEL","KOTAKBANK","LT","M&M","MARUTI","MAXHEALTH",
    "NESTLEIND","NTPC","ONGC","POWERGRID","RELIANCE","SBIN","SBILIFE","SHRIRAMFIN",
    "SUNPHARMA","TATACONSUM","TATAMOTORS","TATASTEEL","TCS","TECHM","TITAN","TRENT",
    "ULTRACEMCO","WIPRO"
]
nse_tickers = [s.strip().upper() + ".NS" if not (s.endswith(".NS") or s.endswith(".BO")) else s for s in tickers]

# %%
nse_tickers
# Out:
# ['ADANIENT.NS',
#  'ADANIPORTS.NS',
#  'APOLLOHOSP.NS',
#  'ASIANPAINT.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BEL.NS',
#  'BHARTIARTL.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'ETERNAL.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HINDUNILVR.NS',
#  'HINDALCO.NS',
#  'ICICIBANK.NS',
#  'INFY.NS',
#  'INDIGO.NS',
#  'ITC.NS',
#  'JIOFIN.NS',
#  'JSWSTEEL.NS',
#  'KOTAKBANK.NS',
#  'LT.NS',
#  'M&M.NS',
#  'MARUTI.NS',
#  'MAXHEALTH.NS',
#  'NESTLEIND.NS',
#  'NTPC.NS',
#  'ONGC.NS',
#  'POWERGRID.NS',
#  'RELIANCE.NS',
#  'SBIN.NS',
#  'SBILIFE.NS',
#  'SHRIRAMFIN.NS',
#  'SUNPHARMA.NS',
#  'TATACONSUM.NS',
#  'TATAMOTORS.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'TRENT.NS',
#  'ULTRACEMCO.NS',
#  'WIPRO.NS']

# %%
# combined_nse_6month.py
import yfinance as yf
import pandas as pd
from tqdm import tqdm
from pathlib import Path
import time

tickers = [
    "ADANIENT","ADANIPORTS","APOLLOHOSP","ASIANPAINT","AXISBANK","BAJAJ-AUTO","BAJFINANCE",
    "BAJAJFINSV","BEL","BHARTIARTL","CIPLA","COALINDIA","DRREDDY","EICHERMOT","ETERNAL",
    "GRASIM","HCLTECH","HDFCBANK","HDFCLIFE","HINDUNILVR","HINDALCO","ICICIBANK","INFY",
    "INDIGO","ITC","JIOFIN","JSWSTEEL","KOTAKBANK","LT","M&M","MARUTI","MAXHEALTH",
    "NESTLEIND","NTPC","ONGC","POWERGRID","RELIANCE","SBIN","SBILIFE","SHRIRAMFIN",
    "SUNPHARMA","TATACONSUM","TATAMOTORS","TATASTEEL","TCS","TECHM","TITAN","TRENT",
    "ULTRACEMCO","WIPRO"
]

OUTPUT_DIR = Path("nse_6month_data")
OUTPUT_DIR.mkdir(exist_ok=True)
OUTFILE = OUTPUT_DIR / "nse_6month_all.csv"

PERIOD = "6mo"
INTERVAL = "1d"
MAX_RETRIES = 3
SLEEP = 1.0  # seconds

def fetch_symbol(symbol):
    ysym = symbol.strip().upper()
    if not (ysym.endswith(".NS") or ysym.endswith(".BO")):
        ysym = ysym + ".NS"
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            df = yf.download(ysym, period=PERIOD, interval=INTERVAL, progress=False)
            if df is None or df.empty:
                print(f"[WARN] No data for {ysym} (attempt {attempt})")
            else:
                # ensure Date is column
                df = df.reset_index()
                # standardize column names
                df = df.rename(columns={
                    "Open":"Open","High":"High","Low":"Low","Close":"Close",
                    "Adj Close":"Adj Close","Volume":"Volume"
                })
                # keep only necessary columns
                cols_keep = ['Date','Open','High','Low','Close','Adj Close','Volume']
                df = df[[c for c in cols_keep if c in df.columns]]
                # add Symbol column (without .NS)
                df['Symbol'] = ysym.replace('.NS','').replace('.BO','')
                return df
        except Exception as e:
            print(f"[ERR] {ysym} attempt {attempt} error: {e}")
        time.sleep(SLEEP * attempt)
    print(f"[SKIP] Skipping {symbol} after {MAX_RETRIES} attempts.")
    return None

def main():
    all_dfs = []
    for sym in tqdm(tickers, desc="Downloading"):
        df = fetch_symbol(sym)
        if df is not None:
            all_dfs.append(df)
    if not all_dfs:
        print("No data collected for any symbol.")
        return

    combined = pd.concat(all_dfs, ignore_index=True)
    # Ensure Date is datetime and sort
    combined['Date'] = pd.to_datetime(combined['Date'])
    combined = combined.sort_values(['Date','Symbol']).reset_index(drop=True)

    # Save long-format CSV
    combined.to_csv(OUTFILE, index=False)
    print(f"\n✅ Saved combined CSV: {OUTFILE.resolve()}")
    print(f"Rows: {len(combined)}, Columns: {list(combined.columns)}")

    # OPTIONAL: also save a pivoted Adjusted Close wide-format file
    try:
        wide = combined.pivot_table(index='Date', columns='Symbol', values='Adj Close')
        wide_file = OUTPUT_DIR / "nse_6month_adjclose_wide.csv"
        wide.to_csv(wide_file)
        print(f"✅ Saved wide Adj Close CSV: {wide_file.resolve()}")
    except Exception as e:
        print(f"[WARN] Could not create wide Adj Close CSV: {e}")

if __name__ == "__main__":
    main()

# %%
import React from 'react';

const stockData = [
  {
    name: 'Cipla',
    day: '+1.49%',
    week: '+6.73%',
    month: '+7.87%',
    performance: ['+.4', '+.3', '+.3', '+.3', -4'],
  },
  {
    name: 'Reliance',
    day: '+0.93%',
    week: '+3.21%',
    month: '+4.56%',
    performance: ['green', 'green', 'red', 'green', 'green'],
  },
  {
    name: 'Infosys',
    day: '-0.72%',
    week: '+1.32%',
    month: '+2.91%',
    performance: ['red', 'green', 'green', 'red', 'green'],
  },
];

const PerformanceCard = ({ name, day, week, month, performance }) => {
  return (
    <div className="bg-white rounded-xl shadow-md p-4 w-64 text-center">
      <div className="bg-[#2f6f89] text-white py-2 rounded-t-md font-semibold text-sm flex justify-between px-3">
        <span>5 Day Performance</span>
        <svg
          xmlns="http://www.w3.org/2000/svg"
          fill="none"
          viewBox="0 0 24 24"
          strokeWidth={2}
          stroke="currentColor"
          className="w-4 h-4 text-white"
        >
          <path strokeLinecap="round" strokeLinejoin="round" d="M6 9l6 6 6-6" />
        </svg>
      </div>
      <div className="flex justify-center gap-2 py-3 bg-white rounded-b-md">
        {performance.map((color, index) => (
          <div
            key={index}
            className={`w-4 h-2 rounded-sm ${
              color === 'green' ? 'bg-green-500' : 'bg-red-500'
            }`}
          ></div>
        ))}
      </div>
      <h2 className="text-blue-600 font-bold text-lg mb-2">{name}</h2>
      <div className="flex justify-between text-left bg-gray-50 rounded-lg p-2">
        <div>
          <span className="text-gray-500 text-sm block">Day:</span>
          <span
            className={`font-semibold text-sm ${day.startsWith('-') ? 'text-red-500' : 'text-green-600'}`}
          >
            {day}
          </span>
        </div>
        <div>
          <span className="text-gray-500 text-sm block">Week:</span>
          <span className="font-semibold text-green-600 text-sm">{week}</span>
        </div>
        <div>
          <span className="text-gray-500 text-sm block">Month:</span>
          <span className="font-semibold text-green-600 text-sm">{month}</span>
        </div>
      </div>
    </div>
  );
};

export default function App() {
  return (
    <div className="flex flex-wrap justify-center gap-6 p-6 bg-gray-100 min-h-screen">
      {stockData.map((stock, index) => (
        <PerformanceCard key={index} {...stock} />
      ))}
    </div>
  );
}
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import React from 'react';

const stockData = [
  {
    name: 'Cipla',
    day: '+1.49%',
    week: '+6.73%',
    month: '+7.87%',
    performance: [1.2, 0.8, 2.3, 1.6, -0.5],
  },
  {
    name: 'Reliance',
    day: '+0.93%',
    week: '+3.21%',
    month: '+4.56%',
    performance: [0.5, 0.9, -0.2, 1.0, 1.3],
  },
  {
    name: 'Infosys',
    day: '-0.72%',
    week: '+1.32%',
    month: '+2.91%',
    performance: [-0.8, 0.4, 0.9, -0.2, 1.1],
  },
];

const PerformanceCard = ({ name, day, week, month, performance }) => {
  return (
    <div className="bg-white rounded-xl shadow-md p-4 w-64 text-center">
      <div className="bg-[#2f6f89] text-white py-2 rounded-t-md font-semibold text-sm flex justify-between px-3">
        <span>5 Day Performance</span>
        <svg
          xmlns="http://www.w3.org/2000/svg"
          fill="none"
          viewBox="0 0 24 24"
          strokeWidth={2}
          stroke="currentColor"
          className="w-4 h-4 text-white"
        >
          <path strokeLinecap="round" strokeLinejoin="round" d="M6 9l6 6 6-6" />
        </svg>
      </div>
      <div className="flex justify-center gap-2 py-3 bg-white rounded-b-md">
        {performance.map((value, index) => (
          <div
            key={index}
            title={`${value.toFixed(2)}%`}
            className={`w-4 h-2 rounded-sm ${value >= 0 ? 'bg-green-500' : 'bg-red-500'}`}
          ></div>
        ))}
      </div>
      <h2 className="text-blue-600 font-bold text-lg mb-2">{name}</h2>
      <div className="flex justify-between text-left bg-gray-50 rounded-lg p-2">
        <div>
          <span className="text-gray-500 text-sm block">Day:</span>
          <span
            className={`font-semibold text-sm ${day.startsWith('-') ? 'text-red-500' : 'text-green-600'}`}
          >
            {day}
          </span>
        </div>
        <div>
          <span className="text-gray-500 text-sm block">Week:</span>
          <span className="font-semibold text-green-600 text-sm">{week}</span>
        </div>
        <div>
          <span className="text-gray-500 text-sm block">Month:</span>
          <span className="font-semibold text-green-600 text-sm">{month}</span>
        </div>
      </div>
    </div>
  );
};

export default function App() {
  return (
    <div className="flex flex-wrap justify-center gap-6 p-6 bg-gray-100 min-h-screen">
      {stockData.map((stock, index) => (
        <PerformanceCard key={index} {...stock} />
      ))}
    </div>
  );
}
# Out:
#   Cell In[13], line 1
#     import React from 'react';
#                  ^
# SyntaxError: invalid syntax

# %%
import yfinance as yf
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# desired single-level columns (yfinance standard)
desired_cols = ['symbol','Close', 'High', 'Low', 'Open', 'Volume']
df_all = pd.DataFrame(columns=desired_cols)
tickers = [
    "ADANIENT",
    "ADANIPORTS",
    "APOLLOHOSP","ASIANPAINT","AXISBANK","BAJAJ-AUTO","BAJFINANCE",
    "BAJAJFINSV","BEL","BHARTIARTL","CIPLA","COALINDIA","DRREDDY","EICHERMOT","ETERNAL",
    "GRASIM","HCLTECH","HDFCBANK","HDFCLIFE","HINDUNILVR","HINDALCO","ICICIBANK","INFY",
    "INDIGO","ITC","JIOFIN","JSWSTEEL","KOTAKBANK","LT","M&M","MARUTI","MAXHEALTH",
    "NESTLEIND","NTPC","ONGC","POWERGRID","RELIANCE","SBIN","SBILIFE","SHRIRAMFIN",
    "SUNPHARMA","TATACONSUM","TATAMOTORS","TATASTEEL","TCS","TECHM","TITAN","TRENT",
    "ULTRACEMCO","WIPRO"
]
start_date = "2024-10-21"
end_date = "2024-10-26"
nse_tickers = [s.strip().upper() + ".NS" if not (s.endswith(".NS") or s.endswith(".BO")) else s for s in tickers]
for symbol in nse_tickers:
    # data = yf.download(symbol, period="1mo")
    data = yf.download(symbol, start=start_date, end=end_date)
    data.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
    data['symbol'] = symbol.replace('.NS','').replace('.BO','')
    df_all = pd.concat([df_all, data], axis=0, ignore_index=False)
df_all = df_all.sort_index().reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df_all
# Out:
#          index      symbol        Close         High          Low  \
# 0   2024-10-21    ADANIENT  2936.148682  3013.409228  2915.459309
# 1   2024-10-21   MAXHEALTH   950.353333   956.196565   938.566946
# 2   2024-10-21     ETERNAL   265.700012   267.000000   254.500000
# 3   2024-10-21   EICHERMOT  4748.873535  4790.730693  4682.286743
# 4   2024-10-21       TRENT  7599.965820  7843.205293  7545.962799
# ..         ...         ...          ...          ...          ...
# 245 2024-10-25      INDIGO  4358.734375  4550.759973  4307.720485
# 246 2024-10-25        INFY  1815.542358  1829.485122  1800.283218
# 247 2024-10-25   ICICIBANK  1245.837036  1259.184123  1224.749746
# 248 2024-10-25  HINDUNILVR  2472.966797  2484.656373  2445.625842
# 249 2024-10-25       WIPRO   261.291321   265.402164   259.872952
#
#             Open    Volume  1d_change
# 0    3003.614187   1051690      -2.30
# 1     939.016378   1750064       1.19
# 2     258.000000  88316110       2.90
# ...

# %%
df_all['1d_change'] =(( df_all['Close']-df_all['Open'])/df_all['Close'])*100
df_all['1d_change'] = df_all['1d_change'].round(2)

# %%
df_all=[df_all[['symbol','1d_chnge']].reset_index(drop=True)]

# %%
summary_df = (
    df_all.groupby('symbol')['1d_change']
    .apply(lambda x: list(x.tail(5)))
    .reset_index(name='5Day Change')
)

# %%
summary_df
# Out:
#         symbol                          5Day Change
# 0     ADANIENT   [-2.3, -4.04, -0.19, -0.38, -5.63]
# 1   ADANIPORTS    [-2.5, -0.87, -1.67, 0.69, -3.13]
# 2   APOLLOHOSP      [0.2, -1.86, 0.31, 0.24, -0.13]
# 3   ASIANPAINT    [1.38, -1.57, -0.34, -0.6, -0.59]
# 4     AXISBANK      [-0.55, -1.57, -1.27, 0.2, 0.2]
# 5   BAJAJ-AUTO    [4.17, -1.27, 2.07, -1.96, -0.92]
# 6   BAJAJFINSV     [-3.62, -2.09, 0.7, 0.12, -2.03]
# 7   BAJFINANCE     [-1.89, -1.83, 5.58, 0.4, -1.89]
# 8          BEL     [-1.42, -3.81, -0.87, 0.87, 0.5]
# 9   BHARTIARTL   [-0.77, 0.01, -0.25, -0.51, -0.91]
# 10       CIPLA  [-1.85, -0.84, -1.29, -0.25, -0.23]
# 11   COALINDIA    [-1.36, -3.56, 1.21, 0.66, -3.69]
# 12     DRREDDY  [-1.08, -0.97, -0.78, -0.93, -0.85]
# 13   EICHERMOT    [0.94, -1.08, -0.96, 0.07, -1.27]
# 14     ETERNAL     [2.9, -4.15, 2.92, -5.07, -0.87]
# 15      GRASIM   [-1.54, -2.36, -0.64, 0.82, -1.91]
# 16     HCLTECH   [-1.72, -0.39, 2.83, -0.01, -0.41]
# ...

# %%
df=pd.read_csv(r"C:\Users\deepa\Downloads\nifty-50.csv")

# %%
# prepare summary and merge with df on NSE Code == symbol
df_summarise = summary_df.rename(columns={'5Day Change':'5day_change'}).copy()
df_summarise['symbol'] = df_summarise['symbol'].str.replace('.NS','', regex=False)

df_merged = df.merge(df_summarise[['symbol','5day_change']], left_on='NSE Code', right_on='symbol', how='left')
df_merged = df_merged.drop(columns=['symbol'])
df_merged.to_csv(r"C:\Users\deepa\Downloads\data1.csv", index=False)

# %%
df_merged
# Out:
#                 Name  BSE Code    NSE Code  \
# 0      Adani Enterp.    512599    ADANIENT
# 1        Adani Ports    532921  ADANIPORTS
# 2   Apollo Hospitals    508869  APOLLOHOSP
# 3       Asian Paints    500820  ASIANPAINT
# 4          Axis Bank    532215    AXISBANK
# 5         Bajaj Auto    532977  BAJAJ-AUTO
# 6      Bajaj Finance    500034  BAJFINANCE
# 7      Bajaj Finserv    532978  BAJAJFINSV
# 8    Bharat Electron    500049         BEL
# 9      Bharti Airtel    532454  BHARTIARTL
# 10             Cipla    500087       CIPLA
# 11        Coal India    533278   COALINDIA
# 12   Dr Reddy's Labs    500124     DRREDDY
# 13     Eicher Motors    505200   EICHERMOT
# 14       Eternal Ltd    543320     ETERNAL
# 15       Grasim Inds    500300      GRASIM
# 16  HCL Technologies    532281     HCLTECH
# 17         HDFC Bank    500180    HDFCBANK
# 18  HDFC Life Insur.    540777    HDFCLIFE
# 19    Hind. Unilever    500696  HINDUNILVR
# 20    Hindalco Inds.    500440    HINDALCO
# ...
